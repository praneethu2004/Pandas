# %% [markdown]
# # Introduction to Pandas in Python

# %% [markdown]
# ## 1. What is Pandas?

# %% [markdown]
# Pandas is an open-source data analysis and data manipulation library for Python.
# It provides powerful data structures such as Series and DataFrame, which allow
# for efficient handling and analysis of structured data.

# %% [markdown]
# Pandas is built on top of NumPy and is widely used for data preprocessing,
# cleaning, transformation, and analysis in data science and machine learning.

# %% [markdown]
# ## Introduction to NumPy

# %% [markdown]
# #### What is NumPy?

# %% [markdown]
# NumPy (Numerical Python) is a powerful Python library used for numerical computing. It provides support for multi-dimensional arrays and mathematical functions, making it an essential library for handling structured data before using Pandas.

# %% [markdown]
# #### Why NumPy?

# %% [markdown]
# 1.Faster than Python lists for numerical operations

# %% [markdown]
# 2.Efficient array manipulations

# %% [markdown]
# 3.Provides mathematical and statistical functions

# %% [markdown]
# ### Installing NumPy

# %% [markdown]
# ##### If you haven’t installed NumPy, you can do so using:

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\kuruv\anaconda3\lib\site-packages (1.26.4)

# %% [markdown]
# ### Importing NumPy

# %%
import numpy as np  # Import NumPy with an alias for easy usage

# %% [markdown]
# ### Creating a NumPy Array

# %%
arr = np.array([1, 2, 3, 4, 5])
print("NumPy Array:", arr)
# Out:
# NumPy Array: [1 2 3 4 5]

# %% [markdown]
# ### Basic Operations with NumPy

# %%
# Creating an array
arr = np.array([10, 20, 30, 40, 50])

# %%
# Performing basic arithmetic
print("Array + 5:", arr + 5)  # Adds 5 to each element
print("Array * 2:", arr * 2)  # Multiplies each element by 2
print("Mean of array:", np.mean(arr))  # Calculates mean
print("Standard Deviation:", np.std(arr))  # Calculates standard deviation
# Out:
# Array + 5: [15 25 35 45 55]
# Array * 2: [ 20  40  60  80 100]
# Mean of array: 30.0
# Standard Deviation: 14.142135623730951

# %% [markdown]
# ## 2. Installing and Importing Pandas
# #### Installing Pandas (if not already installed)

# %%
#Uncomment and run the following line in a Jupyter Notebook cell if you haven't installed Pandas yet.
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\kuruv\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kuruv\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kuruv\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kuruv\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kuruv\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\kuruv\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ### Importing the Pandas Library

# %%
# Importing Pandas
import pandas as pd

# %% [markdown]
# ### Checking Pandas Version

# %%
# Displaying Pandas version
print("Pandas Version:", pd.__version__)
# Out:
# Pandas Version: 2.2.2

# %% [markdown]
# ## 3. Loading Data into a Pandas DataFrame

# %% [markdown]
# #### Reading a CSV File into a DataFrame

# %%
df=pd.read_csv("C:/Users/kuruv/Downloads/deliveries.csv")  # Loading dataset

# %%
df        # Displaying the DataFrame
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball       batter         bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly        P Kumar  BB McCullum             0
# 1          0     2  BB McCullum        P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum        P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum        P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...   ...          ...            ...          ...           ...
# 260915     9     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     9     6      VR Iyer     AK Markram      SS Iyer             1
# 260917    10     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918    10     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919    10     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0              NaN
# 1                0           0         NaN          0              NaN
# 2                1           1       wides          0              NaN
# 3                0           0         NaN          0              NaN
# 4                0           0         NaN          0              NaN
# ...            ...         ...         ...        ...              ...
# 260915           0           1         NaN          0              NaN
# 260916           0           1         NaN          0              NaN
# 260917           0           1         NaN          0              NaN
# 260918           0           1         NaN          0              NaN
# 260919           0           1         NaN          0              NaN
#
#        dismissal_kind fielder
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ...               ...     ...
# 260915            NaN     NaN
# 260916            NaN     NaN
# 260917            NaN     NaN
# 260918            NaN     NaN
# 260919            NaN     NaN
#
# [260920 rows x 17 columns]

# %% [markdown]
# ## 4. Exploring the DataFrame

# %% [markdown]
# #### Displaying Data

# %%
df.head(100)    # Display first 100 rows
# Out:
#     match_id  inning           batting_team                 bowling_team  \
# 0     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ..       ...     ...                    ...                          ...
# 95    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 96    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 97    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 98    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 99    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
#
#     over  ball       batter     bowler  non_striker  batsman_runs  extra_runs  \
# 0      0     1   SC Ganguly    P Kumar  BB McCullum             0           1
# 1      0     2  BB McCullum    P Kumar   SC Ganguly             0           0
# 2      0     3  BB McCullum    P Kumar   SC Ganguly             0           1
# 3      0     4  BB McCullum    P Kumar   SC Ganguly             0           0
# 4      0     5  BB McCullum    P Kumar   SC Ganguly             0           0
# ..   ...   ...          ...        ...          ...           ...         ...
# 95    15     2    DJ Hussey  AA Noffke  BB McCullum             1           0
# 96    15     3  BB McCullum  AA Noffke    DJ Hussey             2           0
# 97    15     4  BB McCullum  AA Noffke    DJ Hussey             0           0
# 98    15     5  BB McCullum  AA Noffke    DJ Hussey             1           0
# 99    15     6    DJ Hussey  AA Noffke  BB McCullum             0           0
#
#     total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0            1     legbyes          0              NaN            NaN     NaN
# 1            0         NaN          0              NaN            NaN     NaN
# 2            1       wides          0              NaN            NaN     NaN
# 3            0         NaN          0              NaN            NaN     NaN
# 4            0         NaN          0              NaN            NaN     NaN
# ..         ...         ...        ...              ...            ...     ...
# 95           1         NaN          0              NaN            NaN     NaN
# 96           2         NaN          0              NaN            NaN     NaN
# 97           0         NaN          0              NaN            NaN     NaN
# 98           1         NaN          0              NaN            NaN     NaN
# 99           0         NaN          0              NaN            NaN     NaN
#
# [100 rows x 17 columns]

# %%
df.tail(100)          # Display last 100 rows
# Out:
#         match_id  inning           batting_team           bowling_team  over  \
# 260820   1426312       1    Sunrisers Hyderabad  Kolkata Knight Riders    13
# 260821   1426312       1    Sunrisers Hyderabad  Kolkata Knight Riders    13
# 260822   1426312       1    Sunrisers Hyderabad  Kolkata Knight Riders    13
# 260823   1426312       1    Sunrisers Hyderabad  Kolkata Knight Riders    13
# 260824   1426312       1    Sunrisers Hyderabad  Kolkata Knight Riders    13
# ...          ...     ...                    ...                    ...   ...
# 260915   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad     9
# 260916   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad     9
# 260917   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad    10
# 260918   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad    10
# 260919   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad    10
#
#         ball      batter         bowler non_striker  batsman_runs  extra_runs  \
# 260820     1  PJ Cummins       CV Varun   H Klaasen             4           0
# 260821     2  PJ Cummins       CV Varun   H Klaasen             0           1
# 260822     3   H Klaasen       CV Varun  PJ Cummins             0           0
# 260823     4   H Klaasen       CV Varun  PJ Cummins             2           0
# 260824     5   H Klaasen       CV Varun  PJ Cummins             1           0
# ...      ...         ...            ...         ...           ...         ...
# 260915     5     SS Iyer     AK Markram     VR Iyer             1           0
# 260916     6     VR Iyer     AK Markram     SS Iyer             1           0
# 260917     1     VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 260918     2     SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 260919     3     VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 260820           4         NaN          0              NaN            NaN
# 260821           1        byes          0              NaN            NaN
# 260822           0         NaN          0              NaN            NaN
# 260823           2         NaN          0              NaN            NaN
# 260824           1         NaN          0              NaN            NaN
# ...            ...         ...        ...              ...            ...
# 260915           1         NaN          0              NaN            NaN
# 260916           1         NaN          0              NaN            NaN
# 260917           1         NaN          0              NaN            NaN
# 260918           1         NaN          0              NaN            NaN
# 260919           1         NaN          0              NaN            NaN
#
#        fielder
# 260820     NaN
# 260821     NaN
# 260822     NaN
# 260823     NaN
# 260824     NaN
# ...        ...
# 260915     NaN
# 260916     NaN
# 260917     NaN
# 260918     NaN
# 260919     NaN
#
# [100 rows x 17 columns]

# %% [markdown]
# ### Checking DataFrame Information

# %%
#  Display column names, data types, and missing values
print("DataFrame Info:")
df.info()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %% [markdown]
# ### Summary Statistics

# %%
#Generate summary statistics for numerical columns
print("\nSummary Statistics:")
df.describe()
# Out:
# Summary Statistics:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       1.000000       0.000000
# 75%         1.000000       0.000000       1.000000       0.000000
# max         6.000000       7.000000       7.000000       1.000000

# %% [markdown]
# ### Checking Data Types of Columns

# %%
df.dtypes               # Display data types of each column
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batter              object
# bowler              object
# non_striker         object
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# extras_type         object
# is_wicket            int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %% [markdown]
# ## 5. Selecting Specific Columns in a DataFrame

# %% [markdown]
# ### Selecting a Single Column

# %%
#Selecting Columns:
#Use df['column'] to select data.
df['inning']       # Selecting the 'inning' column
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 260915    2
# 260916    2
# 260917    2
# 260918    2
# 260919    2
# Name: inning, Length: 260920, dtype: int64

# %% [markdown]
# ### Selecting Multiple Columns

# %%
#Use df[['col1', 'col2']] to select multiple columns.
df[['total_runs', 'fielder']]
# Out:
#         total_runs fielder
# 0                1     NaN
# 1                0     NaN
# 2                1     NaN
# 3                0     NaN
# 4                0     NaN
# ...            ...     ...
# 260915           1     NaN
# 260916           1     NaN
# 260917           1     NaN
# 260918           1     NaN
# 260919           1     NaN
#
# [260920 rows x 2 columns]

# %% [markdown]
# ### Selecting Multiple Columns for a Specific Row Range

# %%
#Selecting multiple columns for the rows from 260900 to 260919
df[['bowler', 'batter', 'batsman_runs']][260900:260919]
# Out:
#                bowler              batter  batsman_runs
# 260900     JD Unadkat  Rahmanullah Gurbaz             1
# 260901     JD Unadkat             VR Iyer             0
# 260902     JD Unadkat             VR Iyer             2
# 260903     JD Unadkat             VR Iyer             1
# 260904     JD Unadkat  Rahmanullah Gurbaz             4
# 260905  Shahbaz Ahmed             VR Iyer             2
# 260906  Shahbaz Ahmed             VR Iyer             0
# 260907  Shahbaz Ahmed  Rahmanullah Gurbaz             0
# 260908  Shahbaz Ahmed  Rahmanullah Gurbaz             6
# 260909  Shahbaz Ahmed  Rahmanullah Gurbaz             0
# 260910  Shahbaz Ahmed             SS Iyer             4
# 260911     AK Markram             VR Iyer             2
# 260912     AK Markram             VR Iyer             0
# 260913     AK Markram             VR Iyer             0
# 260914     AK Markram             VR Iyer             1
# 260915     AK Markram             SS Iyer             1
# 260916     AK Markram             VR Iyer             1
# 260917  Shahbaz Ahmed             VR Iyer             1
# 260918  Shahbaz Ahmed             SS Iyer             1

# %%
# Selecting 'bowler', 'batter', and 'batsman_runs' columns for every alternate row (step=2) within the positional index range from 260900 to 260919
df[['bowler', 'batter', 'batsman_runs']][260900:260919:2]
# Out:
#                bowler              batter  batsman_runs
# 260900     JD Unadkat  Rahmanullah Gurbaz             1
# 260902     JD Unadkat             VR Iyer             2
# 260904     JD Unadkat  Rahmanullah Gurbaz             4
# 260906  Shahbaz Ahmed             VR Iyer             0
# 260908  Shahbaz Ahmed  Rahmanullah Gurbaz             6
# 260910  Shahbaz Ahmed             SS Iyer             4
# 260912     AK Markram             VR Iyer             0
# 260914     AK Markram             VR Iyer             1
# 260916     AK Markram             VR Iyer             1
# 260918  Shahbaz Ahmed             SS Iyer             1

# %%
df[['bowler', 'batter', 'batsman_runs']][0:260919:200000]     # Selecting with a step of 200000
# Out:
#             bowler      batter  batsman_runs
# 0          P Kumar  SC Ganguly             0
# 200000  KA Pollard   AT Rayudu             1

# %% [markdown]
# ## 6. Filtering Rows in a DataFrame

# %% [markdown]
# ### Filtering Rows Based on a Condition

# %%
df[df['batting_team'] == 'Sunrisers Hyderabad']    # Select only rows where batting_team is 'Sunrisers Hyderabad'
# Out:
#         match_id  inning         batting_team           bowling_team  over  \
# 76859     598000       1  Sunrisers Hyderabad          Pune Warriors     0
# 76860     598000       1  Sunrisers Hyderabad          Pune Warriors     0
# 76861     598000       1  Sunrisers Hyderabad          Pune Warriors     0
# 76862     598000       1  Sunrisers Hyderabad          Pune Warriors     0
# 76863     598000       1  Sunrisers Hyderabad          Pune Warriors     0
# ...          ...     ...                  ...                    ...   ...
# 260848   1426312       1  Sunrisers Hyderabad  Kolkata Knight Riders    17
# 260849   1426312       1  Sunrisers Hyderabad  Kolkata Knight Riders    17
# 260850   1426312       1  Sunrisers Hyderabad  Kolkata Knight Riders    18
# 260851   1426312       1  Sunrisers Hyderabad  Kolkata Knight Riders    18
# 260852   1426312       1  Sunrisers Hyderabad  Kolkata Knight Riders    18
#
#         ball      batter      bowler non_striker  batsman_runs  extra_runs  \
# 76859      1    PA Reddy  MN Samuels    PA Patel             1           0
# 76860      2    PA Patel  MN Samuels    PA Reddy             1           0
# 76861      3    PA Reddy  MN Samuels    PA Patel             0           1
# 76862      4    PA Reddy  MN Samuels    PA Patel             0           0
# 76863      5    PA Reddy  MN Samuels    PA Patel             1           0
# ...      ...         ...         ...         ...           ...         ...
# 260848     5  JD Unadkat   SP Narine  PJ Cummins             0           0
# 260849     6     B Kumar   SP Narine  PJ Cummins             0           0
# 260850     1  PJ Cummins  AD Russell     B Kumar             0           0
# 260851     2  PJ Cummins  AD Russell     B Kumar             0           0
# 260852     3  PJ Cummins  AD Russell     B Kumar             0           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 76859            1         NaN          0              NaN            NaN
# 76860            1         NaN          0              NaN            NaN
# 76861            1       wides          0              NaN            NaN
# 76862            0         NaN          0              NaN            NaN
# 76863            1         NaN          0              NaN            NaN
# ...            ...         ...        ...              ...            ...
# 260848           0         NaN          1       JD Unadkat            lbw
# 260849           0         NaN          0              NaN            NaN
# 260850           0         NaN          0              NaN            NaN
# 260851           0         NaN          0              NaN            NaN
# 260852           0         NaN          1       PJ Cummins         caught
#
#          fielder
# 76859        NaN
# 76860        NaN
# 76861        NaN
# 76862        NaN
# 76863        NaN
# ...          ...
# 260848       NaN
# 260849       NaN
# 260850       NaN
# 260851       NaN
# 260852  MA Starc
#
# [21843 rows x 17 columns]

# %% [markdown]
# ### Filtering Rows to Exclude Specific Teams

# %%
#Filtering Rows:
df[~df["batting_team"].isin(["Sunrisers Hyderabad", "Kolkata Knight Riders", "Royal Challengers Bangalore"])]
#This will return a DataFrame excluding rows where the batting_team is Sunrisers Hyderabad or Kolkata Knight Riders or Royal Challengers Bangalore.
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 225       335983       1  Chennai Super Kings      Kings XI Punjab     0
# 226       335983       1  Chennai Super Kings      Kings XI Punjab     0
# 227       335983       1  Chennai Super Kings      Kings XI Punjab     0
# 228       335983       1  Chennai Super Kings      Kings XI Punjab     0
# 229       335983       1  Chennai Super Kings      Kings XI Punjab     0
# ...          ...     ...                  ...                  ...   ...
# 260731   1426311       2     Rajasthan Royals  Sunrisers Hyderabad    19
# 260732   1426311       2     Rajasthan Royals  Sunrisers Hyderabad    19
# 260733   1426311       2     Rajasthan Royals  Sunrisers Hyderabad    19
# 260734   1426311       2     Rajasthan Royals  Sunrisers Hyderabad    19
# 260735   1426311       2     Rajasthan Royals  Sunrisers Hyderabad    19
#
#         ball       batter       bowler non_striker  batsman_runs  extra_runs  \
# 225        1     PA Patel        B Lee   ML Hayden             0           0
# 226        2     PA Patel        B Lee   ML Hayden             0           0
# 227        3     PA Patel        B Lee   ML Hayden             1           0
# 228        4    ML Hayden        B Lee    PA Patel             0           0
# 229        5    ML Hayden        B Lee    PA Patel             4           0
# ...      ...          ...          ...         ...           ...         ...
# 260731     2  Dhruv Jurel  T Natarajan    TA Boult             4           0
# 260732     3  Dhruv Jurel  T Natarajan    TA Boult             0           0
# 260733     4  Dhruv Jurel  T Natarajan    TA Boult             0           0
# 260734     5  Dhruv Jurel  T Natarajan    TA Boult             0           0
# 260735     6  Dhruv Jurel  T Natarajan    TA Boult             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 225              0         NaN          0              NaN            NaN
# 226              0         NaN          0              NaN            NaN
# 227              1         NaN          0              NaN            NaN
# 228              0         NaN          0              NaN            NaN
# 229              4         NaN          0              NaN            NaN
# ...            ...         ...        ...              ...            ...
# 260731           4         NaN          0              NaN            NaN
# 260732           0         NaN          0              NaN            NaN
# 260733           0         NaN          0              NaN            NaN
# 260734           0         NaN          0              NaN            NaN
# 260735           1         NaN          0              NaN            NaN
#
#        fielder
# 225        NaN
# 226        NaN
# 227        NaN
# 228        NaN
# 229        NaN
# ...        ...
# 260731     NaN
# 260732     NaN
# 260733     NaN
# 260734     NaN
# 260735     NaN
#
# [181358 rows x 17 columns]

# %% [markdown]
# ### Filtering Rows Where 'match_id' is Greater Than a Certain Value

# %%
df[df['match_id'] > 450000]
# Filtering the DataFrame to include only rows where 'match_id' is greater than 450000
# Out:
#         match_id  inning           batting_team           bowling_team  over  \
# 41593     501198       1    Chennai Super Kings  Kolkata Knight Riders     0
# 41594     501198       1    Chennai Super Kings  Kolkata Knight Riders     0
# 41595     501198       1    Chennai Super Kings  Kolkata Knight Riders     0
# 41596     501198       1    Chennai Super Kings  Kolkata Knight Riders     0
# 41597     501198       1    Chennai Super Kings  Kolkata Knight Riders     0
# ...          ...     ...                    ...                    ...   ...
# 260915   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad     9
# 260916   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad     9
# 260917   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad    10
# 260918   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad    10
# 260919   1426312       2  Kolkata Knight Riders    Sunrisers Hyderabad    10
#
#         ball      batter         bowler non_striker  batsman_runs  extra_runs  \
# 41593      1  S Anirudha  Iqbal Abdulla     M Vijay             0           0
# 41594      2  S Anirudha  Iqbal Abdulla     M Vijay             1           0
# 41595      3     M Vijay  Iqbal Abdulla  S Anirudha             0           0
# 41596      4     M Vijay  Iqbal Abdulla  S Anirudha             0           0
# 41597      5     M Vijay  Iqbal Abdulla  S Anirudha             4           0
# ...      ...         ...            ...         ...           ...         ...
# 260915     5     SS Iyer     AK Markram     VR Iyer             1           0
# 260916     6     VR Iyer     AK Markram     SS Iyer             1           0
# 260917     1     VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 260918     2     SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 260919     3     VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 41593            0         NaN          0              NaN            NaN
# 41594            1         NaN          0              NaN            NaN
# 41595            0         NaN          0              NaN            NaN
# 41596            0         NaN          0              NaN            NaN
# 41597            4         NaN          0              NaN            NaN
# ...            ...         ...        ...              ...            ...
# 260915           1         NaN          0              NaN            NaN
# 260916           1         NaN          0              NaN            NaN
# 260917           1         NaN          0              NaN            NaN
# 260918           1         NaN          0              NaN            NaN
# 260919           1         NaN          0              NaN            NaN
#
#        fielder
# 41593      NaN
# 41594      NaN
# 41595      NaN
# 41596      NaN
# 41597      NaN
# ...        ...
# 260915     NaN
# 260916     NaN
# 260917     NaN
# 260918     NaN
# 260919     NaN
#
# [219327 rows x 17 columns]

# %% [markdown]
# ## 7. Counting Values in a DataFrame

# %% [markdown]
# ### Counting Occurrences of a Specific Value in a Column

# %%
df[df['batter'] == "SS Iyer"].shape[0]
# Count the number of times "SS Iyer" appears in the 'batter' column
# Out:
# 2545

# %%
df['batter'].value_counts().get("SS Iyer", 0)
# Count the number of times "SS Iyer" appears in the 'batter' column
# Out:
# 2545

# %% [markdown]
# ## 8.Handling Missing Values

# %% [markdown]
# ### Checking for Missing Values

# %%
# Check for missing values
print("\nMissing Values:")
df.isnull().sum()
# Out:
# Missing Values:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %% [markdown]
# ### Detecting Missing Values in the DataFrame

# %%
# Returns a boolean DataFrame indicating missing values
df.isnull()
# Out:
#         match_id  inning  batting_team  bowling_team   over   ball  batter  \
# 0          False   False         False         False  False  False   False
# 1          False   False         False         False  False  False   False
# 2          False   False         False         False  False  False   False
# 3          False   False         False         False  False  False   False
# 4          False   False         False         False  False  False   False
# ...          ...     ...           ...           ...    ...    ...     ...
# 260915     False   False         False         False  False  False   False
# 260916     False   False         False         False  False  False   False
# 260917     False   False         False         False  False  False   False
# 260918     False   False         False         False  False  False   False
# 260919     False   False         False         False  False  False   False
#
#         bowler  non_striker  batsman_runs  extra_runs  total_runs  \
# 0        False        False         False       False       False
# 1        False        False         False       False       False
# 2        False        False         False       False       False
# 3        False        False         False       False       False
# 4        False        False         False       False       False
# ...        ...          ...           ...         ...         ...
# 260915   False        False         False       False       False
# 260916   False        False         False       False       False
# 260917   False        False         False       False       False
# 260918   False        False         False       False       False
# 260919   False        False         False       False       False
#
#         extras_type  is_wicket  player_dismissed  dismissal_kind  fielder
# 0             False      False              True            True     True
# 1              True      False              True            True     True
# 2             False      False              True            True     True
# 3              True      False              True            True     True
# 4              True      False              True            True     True
# ...             ...        ...               ...             ...      ...
# 260915         True      False              True            True     True
# 260916         True      False              True            True     True
# 260917         True      False              True            True     True
# 260918         True      False              True            True     True
# 260919         True      False              True            True     True
#
# [260920 rows x 17 columns]

# %% [markdown]
# ### Removing Rows with Missing Values

# %%
df.dropna()
#Remove rows with missing values
# Out:
#         match_id  inning                 batting_team  \
# 6670      336010       1        Kolkata Knight Riders
# 9022      336020       1             Delhi Daredevils
# 21707     392217       2          Chennai Super Kings
# 21927     392218       2  Royal Challengers Bangalore
# 22808     392222       1              Kings XI Punjab
# 24387     392228       2              Deccan Chargers
# 29246     419114       2             Delhi Daredevils
# 38560     419153       1        Kolkata Knight Riders
# 40074     419159       2          Chennai Super Kings
# 40814     419162       2  Royal Challengers Bangalore
# 42421     501201       1             Delhi Daredevils
# 46496     501219       2        Kolkata Knight Riders
# 54075     501251       2               Mumbai Indians
# 74829     548375       2                Pune Warriors
# 79791     598012       1  Royal Challengers Bangalore
# 99050     729315       3        Kolkata Knight Riders
# 100461    733979       2        Kolkata Knight Riders
# 101590    733989       1          Sunrisers Hyderabad
# 102297    733995       2          Chennai Super Kings
# 106634    734031       1               Mumbai Indians
# 109324    829707       2             Delhi Daredevils
# 109961    829713       1        Kolkata Knight Riders
# 115702    829763       1  Royal Challengers Bangalore
# 116439    829769       2             Rajasthan Royals
# 117053    829775       2              Kings XI Punjab
# 120237    829803       1              Kings XI Punjab
# 122130    829821       1  Royal Challengers Bangalore
# 124384    980917       1               Mumbai Indians
# 130652    980969       1      Rising Pune Supergiants
# 133061    980989       2        Kolkata Knight Riders
# 136969   1082592       1               Mumbai Indians
# 142909   1082617       1        Kolkata Knight Riders
# 144492   1082625       1                Gujarat Lions
# 147815   1082639       1              Kings XI Punjab
# 153403   1136573       2             Delhi Daredevils
# 153675   1136574       2  Royal Challengers Bangalore
# 159860   1136600       2              Kings XI Punjab
# 165867   1175360       2          Chennai Super Kings
# 178494   1181766       2               Delhi Capitals
# 201184   1254089       1          Chennai Super Kings
# 208092   1304047       1          Chennai Super Kings
# 210216   1304055       2               Mumbai Indians
# 220309   1304097       1               Mumbai Indians
# 224880   1304116       1          Sunrisers Hyderabad
# 225101   1312197       1             Rajasthan Royals
# 225102   1312197       1             Rajasthan Royals
# 233329   1359505       1                 Punjab Kings
# 233639   1359506       1  Royal Challengers Bangalore
# 234879   1359511       1             Rajasthan Royals
# 236509   1359518       1               Delhi Capitals
# 242686   1359544       1  Royal Challengers Bangalore
# 243398   1370352       1               Gujarat Titans
# 249678   1426262       2               Gujarat Titans
# 251484   1426270       1               Gujarat Titans
# 252273   1426273       2               Delhi Capitals
# 260426   1426310       2             Rajasthan Royals
#
#                        bowling_team  over  ball            batter  \
# 6670    Royal Challengers Bangalore     8     6         DJ Hussey
# 9022                Deccan Chargers    15     2         G Gambhir
# 21707              Rajasthan Royals    16     6         ML Hayden
# 21927                Mumbai Indians    13     2  RE van der Merwe
# 22808                Mumbai Indians    17     6            K Goel
# 24387         Kolkata Knight Riders    17     1         A Symonds
# 29246                Mumbai Indians     8     5        KD Karthik
# 38560           Chennai Super Kings     4     1         DJ Hussey
# 40074               Kings XI Punjab     4     1           M Vijay
# 40814                Mumbai Indians     6     2      KP Pietersen
# 42421                Mumbai Indians    16     4          UT Yadav
# 46496          Kochi Tuskers Kerala    16     6         MK Tiwary
# 54075               Kings XI Punjab     3     6         RG Sharma
# 74829         Kolkata Knight Riders     7     5         MJ Clarke
# 79791           Chennai Super Kings     8     5        MA Agarwal
# 99050              Rajasthan Royals     0     1          SA Yadav
# 100461             Rajasthan Royals    15     1         MK Pandey
# 101590             Rajasthan Royals    19     3         IK Pathan
# 102297               Mumbai Indians     7     7          SK Raina
# 106634             Delhi Daredevils    19     4         JJ Bumrah
# 109324          Chennai Super Kings    18     5          A Mishra
# 109961  Royal Challengers Bangalore    19     6   Shakib Al Hasan
# 115702             Rajasthan Royals    16     3           SN Khan
# 116439               Mumbai Indians    19     5         STR Binny
# 117053               Mumbai Indians    18     5           WP Saha
# 120237  Royal Challengers Bangalore     5     5         DA Miller
# 122130          Chennai Super Kings    19     4          HV Patel
# 124384                Gujarat Lions     8     6        JC Buttler
# 130652  Royal Challengers Bangalore    14     2         SS Tiwary
# 133061      Rising Pune Supergiants     0     2        RV Uthappa
# 136969       Rising Pune Supergiant    19     6         HH Pandya
# 142909  Royal Challengers Bangalore     9     2         YK Pathan
# 144492               Mumbai Indians     8     2        KD Karthik
# 147815        Kolkata Knight Riders    17     6           WP Saha
# 153403        Kolkata Knight Riders     0     6            JJ Roy
# 153675               Mumbai Indians     9     4     Mandeep Singh
# 159860             Rajasthan Royals     2     1          CH Gayle
# 165867               Delhi Capitals     6     5         SR Watson
# 178494          Sunrisers Hyderabad     7     4          S Dhawan
# 201184             Rajasthan Royals    14     4            MM Ali
# 208092        Kolkata Knight Riders     7     6        RV Uthappa
# 210216             Rajasthan Royals    18     9        KA Pollard
# 220309               Gujarat Titans    18     3       Tilak Varma
# 224880                 Punjab Kings    19     6        R Shepherd
# 225101               Gujarat Titans    19     6        JC Buttler
# 225102               Gujarat Titans    19     7          R Ashwin
# 233329               Mumbai Indians     9     2    LS Livingstone
# 233639             Rajasthan Royals    19     1      PWH de Silva
# 234879          Chennai Super Kings    19     4        D Padikkal
# 236509               Gujarat Titans     1     2           PK Garg
# 242686               Gujarat Titans     9     3         MK Lomror
# 243398               Mumbai Indians     6     3           WP Saha
# 249678             Rajasthan Royals    15     3      Shubman Gill
# 251484               Delhi Capitals     8     5   M Shahrukh Khan
# 252273          Sunrisers Hyderabad     8     5     Abishek Porel
# 260426  Royal Challengers Bengaluru    10     1         SV Samson
#
#                    bowler       non_striker  batsman_runs  extra_runs  \
# 6670             A Kumble           T Taibu             0           1
# 9022              PP Ojha          S Dhawan             0           1
# 21707            SK Warne       S Badrinath             0           1
# 21927     Harbhajan Singh        MV Boucher             0           1
# 22808          SL Malinga         PP Chawla             0           1
# 24387    Mashrafe Mortaza         RG Sharma             0           1
# 29246     Harbhajan Singh       MF Maharoof             0           1
# 38560            R Ashwin         MK Tiwary             0           1
# 40074            RR Powar          SK Raina             0           1
# 40814     Harbhajan Singh          R Dravid             0           1
# 42421     Harbhajan Singh  RE van der Merwe             0           1
# 46496           RA Jadeja          R Bhatia             0           1
# 54075        Bipul Sharma       AC Blizzard             0           1
# 74829           YK Pathan          JD Ryder             0           1
# 79791            R Ashwin           V Kohli             0           1
# 99050         JP Faulkner   Shakib Al Hasan             0           1
# 100461           PV Tambe   Shakib Al Hasan             0           1
# 101590        JP Faulkner          DW Steyn             0           1
# 102297         KA Pollard          DR Smith             0           1
# 106634         WD Parnell           S Gopal             0           1
# 109324            A Nehra         JA Morkel             0           1
# 109961           VR Aaron        AD Russell             0           1
# 115702          SR Watson        KD Karthik             1           1
# 116439      R Vinay Kumar        TG Southee             1           1
# 117053         SL Malinga         GJ Bailey             0           1
# 120237          YS Chahal         GJ Bailey             0           1
# 122130           DJ Bravo           SN Khan             0           1
# 124384          SB Jakati          PA Patel             0           1
# 130652          YS Chahal         AM Rahane             0           1
# 133061           R Ashwin         G Gambhir             0           1
# 136969           AB Dinda        TG Southee             0           1
# 142909          YS Chahal         MK Pandey             0           1
# 144492          KH Pandya      Ishan Kishan             0           1
# 147815      Kuldeep Yadav          AR Patel             0           1
# 153403          PP Chawla         G Gambhir             0           1
# 153675          KH Pandya           V Kohli             0           1
# 159860          K Gowtham          KL Rahul             0           1
# 165867           A Mishra          SK Raina             0           1
# 178494           DJ Hooda           PP Shaw             0           1
# 201184          R Tewatia        RD Gaikwad             0           1
# 208092           CV Varun         AT Rayudu             0           1
# 210216  M Prasidh Krishna          M Ashwin             0           1
# 220309        LH Ferguson          TH David             0           1
# 224880           NT Ellis           B Kumar             0           1
# 225101         Yash Dayal           R Parag             1           1
# 225102         Yash Dayal           R Parag             0           1
# 233329          PP Chawla     Atharva Taide             0           1
# 233639     Sandeep Sharma        KD Karthik             0           1
# 234879        M Pathirana       Dhruv Jurel             0           1
# 236509          HH Pandya         DA Warner             0           1
# 242686         Noor Ahmad           V Kohli             0           1
# 243398          PP Chawla      Shubman Gill             0           1
# 249678          YS Chahal         R Tewatia             0           1
# 251484           T Stubbs         R Tewatia             0           1
# 252273         M Markande          T Stubbs             0           1
# 260426          KV Sharma           R Parag             0           1
#
#         total_runs extras_type  is_wicket  player_dismissed dismissal_kind  \
# 6670             1     legbyes          1         DJ Hussey        run out
# 9022             1       wides          1         G Gambhir        stumped
# 21707            1       wides          1         ML Hayden        stumped
# 21927            1       wides          1  RE van der Merwe        stumped
# 22808            1       wides          1         PP Chawla        run out
# 24387            1     noballs          1         A Symonds        run out
# 29246            1       wides          1        KD Karthik        stumped
# 38560            1       wides          1         DJ Hussey        stumped
# 40074            1       wides          1           M Vijay        stumped
# 40814            1       wides          1      KP Pietersen        stumped
# 42421            1       wides          1          UT Yadav        stumped
# 46496            1       wides          1         MK Tiwary        stumped
# 54075            1       wides          1         RG Sharma        stumped
# 74829            1       wides          1         MJ Clarke        stumped
# 79791            1       wides          1        MA Agarwal        stumped
# 99050            1     legbyes          1          SA Yadav        run out
# 100461           1       wides          1         MK Pandey        stumped
# 101590           1       wides          1          DW Steyn        run out
# 102297           1       wides          1          SK Raina        stumped
# 106634           1       wides          1           S Gopal        run out
# 109324           1       wides          1          A Mishra        run out
# 109961           1       wides          1   Shakib Al Hasan        run out
# 115702           2     noballs          1        KD Karthik        run out
# 116439           2     noballs          1        TG Southee        run out
# 117053           1       wides          1         GJ Bailey        run out
# 120237           1       wides          1         DA Miller        stumped
# 122130           1       wides          1          HV Patel        run out
# 124384           1       wides          1        JC Buttler        stumped
# 130652           1       wides          1         SS Tiwary        stumped
# 133061           1       wides          1        RV Uthappa        stumped
# 136969           1       wides          1        TG Southee        run out
# 142909           1       wides          1         YK Pathan        stumped
# 144492           1       wides          1        KD Karthik        stumped
# 147815           1       wides          1           WP Saha        stumped
# 153403           1       wides          1            JJ Roy        stumped
# 153675           1       wides          1     Mandeep Singh        stumped
# 159860           1       wides          1          CH Gayle        stumped
# 165867           1       wides          1         SR Watson        stumped
# 178494           1       wides          1          S Dhawan        stumped
# 201184           1       wides          1            MM Ali        stumped
# 208092           1       wides          1        RV Uthappa        stumped
# 210216           1     noballs          1          M Ashwin        run out
# 220309           1     noballs          1       Tilak Varma        run out
# 224880           1     noballs          1           B Kumar        run out
# 225101           2     noballs          1        JC Buttler        run out
# 225102           1       wides          1           R Parag        run out
# 233329           1       wides          1    LS Livingstone        stumped
# 233639           1       wides          1      PWH de Silva        run out
# 234879           1       wides          1       Dhruv Jurel        run out
# 236509           1     noballs          1         DA Warner        run out
# 242686           1       wides          1         MK Lomror        stumped
# 243398           1       wides          1           WP Saha        stumped
# 249678           1       wides          1      Shubman Gill        stumped
# 251484           1       wides          1   M Shahrukh Khan        stumped
# 252273           1       wides          1     Abishek Porel        stumped
# 260426           1       wides          1         SV Samson        stumped
#
#                  fielder
# 6670            DW Steyn
# 9022        AC Gilchrist
# 21707            NV Ojha
# 21927        YV Takawale
# 22808        YV Takawale
# 24387   Mashrafe Mortaza
# 29246            AP Tare
# 38560           MS Dhoni
# 40074      KC Sangakkara
# 40814          AT Rayudu
# 42421          DJ Jacobs
# 46496           PA Patel
# 54075       AC Gilchrist
# 74829        BB McCullum
# 79791           MS Dhoni
# 99050          SV Samson
# 100461         SV Samson
# 101590         SV Samson
# 102297         CM Gautam
# 106634        KD Karthik
# 109324          MS Dhoni
# 109961        KD Karthik
# 115702        TG Southee
# 116439        KA Pollard
# 117053          PA Patel
# 120237        KD Karthik
# 122130          MS Dhoni
# 124384        KD Karthik
# 130652          KL Rahul
# 133061          MS Dhoni
# 136969          MS Dhoni
# 142909         KM Jadhav
# 144492          PA Patel
# 147815        RV Uthappa
# 153403        KD Karthik
# 153675      Ishan Kishan
# 159860        JC Buttler
# 165867           RR Pant
# 178494           WP Saha
# 201184         SV Samson
# 208092        SP Jackson
# 210216         SV Samson
# 220309         HH Pandya
# 224880         JM Sharma
# 225101           WP Saha
# 225102           WP Saha
# 233329      Ishan Kishan
# 233639         SV Samson
# 234879          MS Dhoni
# 236509       Rashid Khan
# 242686           WP Saha
# 243398      Ishan Kishan
# 249678         SV Samson
# 251484           RR Pant
# 252273         H Klaasen
# 260426        KD Karthik

# %%
df           # Displaying the DataFrame
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball       batter         bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly        P Kumar  BB McCullum             0
# 1          0     2  BB McCullum        P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum        P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum        P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...   ...          ...            ...          ...           ...
# 260915     9     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     9     6      VR Iyer     AK Markram      SS Iyer             1
# 260917    10     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918    10     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919    10     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0              NaN
# 1                0           0         NaN          0              NaN
# 2                1           1       wides          0              NaN
# 3                0           0         NaN          0              NaN
# 4                0           0         NaN          0              NaN
# ...            ...         ...         ...        ...              ...
# 260915           0           1         NaN          0              NaN
# 260916           0           1         NaN          0              NaN
# 260917           0           1         NaN          0              NaN
# 260918           0           1         NaN          0              NaN
# 260919           0           1         NaN          0              NaN
#
#        dismissal_kind fielder
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ...               ...     ...
# 260915            NaN     NaN
# 260916            NaN     NaN
# 260917            NaN     NaN
# 260918            NaN     NaN
# 260919            NaN     NaN
#
# [260920 rows x 17 columns]

# %% [markdown]
# ### Filling Missing Values

# %%
df.fillna(9)
# Temporarily replace missing values with 9
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball       batter         bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly        P Kumar  BB McCullum             0
# 1          0     2  BB McCullum        P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum        P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum        P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...   ...          ...            ...          ...           ...
# 260915     9     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     9     6      VR Iyer     AK Markram      SS Iyer             1
# 260917    10     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918    10     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919    10     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0                9
# 1                0           0           9          0                9
# 2                1           1       wides          0                9
# 3                0           0           9          0                9
# 4                0           0           9          0                9
# ...            ...         ...         ...        ...              ...
# 260915           0           1           9          0                9
# 260916           0           1           9          0                9
# 260917           0           1           9          0                9
# 260918           0           1           9          0                9
# 260919           0           1           9          0                9
#
#        dismissal_kind fielder
# 0                   9       9
# 1                   9       9
# 2                   9       9
# 3                   9       9
# 4                   9       9
# ...               ...     ...
# 260915              9       9
# 260916              9       9
# 260917              9       9
# 260918              9       9
# 260919              9       9
#
# [260920 rows x 17 columns]

# %%
df['extras_type'] = df['extras_type'].fillna(0)
  # Fills missing values with 0 permanently
#permanently filling of null values with specified value

# %%
df                  # Displaying the DataFrame
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball       batter         bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly        P Kumar  BB McCullum             0
# 1          0     2  BB McCullum        P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum        P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum        P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...   ...          ...            ...          ...           ...
# 260915     9     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     9     6      VR Iyer     AK Markram      SS Iyer             1
# 260917    10     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918    10     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919    10     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0              NaN
# 1                0           0           0          0              NaN
# 2                1           1       wides          0              NaN
# 3                0           0           0          0              NaN
# 4                0           0           0          0              NaN
# ...            ...         ...         ...        ...              ...
# 260915           0           1           0          0              NaN
# 260916           0           1           0          0              NaN
# 260917           0           1           0          0              NaN
# 260918           0           1           0          0              NaN
# 260919           0           1           0          0              NaN
#
#        dismissal_kind fielder
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ...               ...     ...
# 260915            NaN     NaN
# 260916            NaN     NaN
# 260917            NaN     NaN
# 260918            NaN     NaN
# 260919            NaN     NaN
#
# [260920 rows x 17 columns]

# %% [markdown]
# ## 9. Selecting Data using Indexing

# %% [markdown]
# ### Integer-Based Indexing with iloc[]

# %%
#Select data by integer-based indexing
df.iloc[50000:55000]
# Out:
#        match_id  inning                 batting_team           bowling_team  \
# 50000    501234       1              Kings XI Punjab  Kolkata Knight Riders
# 50001    501234       1              Kings XI Punjab  Kolkata Knight Riders
# 50002    501234       1              Kings XI Punjab  Kolkata Knight Riders
# 50003    501234       1              Kings XI Punjab  Kolkata Knight Riders
# 50004    501234       1              Kings XI Punjab  Kolkata Knight Riders
# ...         ...     ...                          ...                    ...
# 54995    501255       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 54996    501255       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 54997    501255       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 54998    501255       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 54999    501255       2  Royal Challengers Bangalore  Kolkata Knight Riders
#
#        over  ball          batter         bowler     non_striker  \
# 50000    14     4      KD Karthik  Iqbal Abdulla       DJ Hussey
# 50001    14     5       DJ Hussey  Iqbal Abdulla      KD Karthik
# 50002    14     6       DJ Hussey  Iqbal Abdulla      KD Karthik
# 50003    15     1      KD Karthik       R Bhatia    Bipul Sharma
# 50004    15     2      KD Karthik       R Bhatia    Bipul Sharma
# ...     ...   ...             ...            ...             ...
# 54995     9     5          M Kaif       L Balaji  AB de Villiers
# 54996     9     6  AB de Villiers       L Balaji          M Kaif
# 54997     9     7  AB de Villiers       L Balaji          M Kaif
# 54998    10     1          M Kaif     JD Unadkat  AB de Villiers
# 54999    10     2          M Kaif     JD Unadkat  AB de Villiers
#
#        batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 50000             1           0           1           0          0
# 50001             0           0           0           0          0
# 50002             0           0           0           0          1
# 50003             0           0           0           0          0
# 50004             0           0           0           0          0
# ...             ...         ...         ...         ...        ...
# 54995             1           0           1           0          0
# 54996             0           0           0           0          0
# 54997             0           0           0           0          0
# 54998             0           0           0           0          0
# 54999             4           0           4           0          0
#
#       player_dismissed dismissal_kind fielder
# 50000              NaN            NaN     NaN
# 50001              NaN            NaN     NaN
# 50002        DJ Hussey            lbw     NaN
# 50003              NaN            NaN     NaN
# 50004              NaN            NaN     NaN
# ...                ...            ...     ...
# 54995              NaN            NaN     NaN
# 54996              NaN            NaN     NaN
# 54997              NaN            NaN     NaN
# 54998              NaN            NaN     NaN
# 54999              NaN            NaN     NaN
#
# [5000 rows x 17 columns]

# %%
# Selecting a specific value (Row index 10, Column index 2)
df.iloc[10, 2]
# Out:
# 'Kolkata Knight Riders'

# %%
# Selecting a range of rows (first 2 rows)
df.iloc[0:2]
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0           0          0              NaN            NaN     NaN

# %%
# Selecting specific rows and columns
df.iloc[0:3, 1:3]
# Out:
#    inning           batting_team
# 0       1  Kolkata Knight Riders
# 1       1  Kolkata Knight Riders
# 2       1  Kolkata Knight Riders

# %% [markdown]
# ### Label-Based Indexing with loc[]

# %%
# Selecting a row by label (index)
print(df.loc[60])
# Out:
# match_id                                 335982
# inning                                        1
# batting_team              Kolkata Knight Riders
# bowling_team        Royal Challengers Bangalore
# over                                          9
# ball                                          5
# batter                              BB McCullum
# bowler                                 SB Joshi
# non_striker                          RT Ponting
# batsman_runs                                  6
# extra_runs                                    0
# total_runs                                    6
# extras_type                                   0
# is_wicket                                     0
# player_dismissed                            NaN
# dismissal_kind                              NaN
# fielder                                     NaN
# Name: 60, dtype: object

# %%
# Selecting multiple rows
df.loc[[0, 100, 200]]
# Out:
#      match_id  inning                 batting_team  \
# 0      335982       1        Kolkata Knight Riders
# 100    335982       1        Kolkata Knight Riders
# 200    335982       2  Royal Challengers Bangalore
#
#                     bowling_team  over  ball       batter      bowler  \
# 0    Royal Challengers Bangalore     0     1   SC Ganguly     P Kumar
# 100  Royal Challengers Bangalore    16     1  BB McCullum      Z Khan
# 200        Kolkata Knight Riders    11     4       Z Khan  SC Ganguly
#
#      non_striker  batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0    BB McCullum             0           1           1     legbyes          0
# 100    DJ Hussey             1           0           1           0          0
# 200      P Kumar             1           0           1           0          0
#
#     player_dismissed dismissal_kind fielder
# 0                NaN            NaN     NaN
# 100              NaN            NaN     NaN
# 200              NaN            NaN     NaN

# %%
# Selecting a specific column
print(df.loc[: "over"]) # All rows, only 'over' column
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball       batter         bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly        P Kumar  BB McCullum             0
# 1          0     2  BB McCullum        P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum        P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum        P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...   ...          ...            ...          ...           ...
# 260915     9     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     9     6      VR Iyer     AK Markram      SS Iyer             1
# 260917    10     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918    10     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919    10     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0              NaN
# 1                0           0           0          0              NaN
# 2                1           1       wides          0              NaN
# 3                0           0           0          0              NaN
# 4                0           0           0          0              NaN
# ...            ...         ...         ...        ...              ...
# 260915           0           1           0          0              NaN
# 260916           0           1           0          0              NaN
# 260917           0           1           0          0              NaN
# 260918           0           1           0          0              NaN
# 260919           0           1           0          0              NaN
#
#        dismissal_kind fielder
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ...               ...     ...
# 260915            NaN     NaN
# 260916            NaN     NaN
# 260917            NaN     NaN
# 260918            NaN     NaN
# 260919            NaN     NaN
#
# [260920 rows x 17 columns]

# %%
# Selecting multiple columns
print(df.loc[:, ["non_striker", "dismissal_kind"]])   # All rows, only 'non_striker', 'dismissal_kind' columns
# Out:
#         non_striker dismissal_kind
# 0       BB McCullum            NaN
# 1        SC Ganguly            NaN
# 2        SC Ganguly            NaN
# 3        SC Ganguly            NaN
# 4        SC Ganguly            NaN
# ...             ...            ...
# 260915      VR Iyer            NaN
# 260916      SS Iyer            NaN
# 260917      SS Iyer            NaN
# 260918      VR Iyer            NaN
# 260919      SS Iyer            NaN
#
# [260920 rows x 2 columns]

# %%
# Selecting a specific value (Row 2, Column 'City')
print(df.loc[2, "dismissal_kind"])
# Out:
# nan

# %% [markdown]
# ## 10.Filtering Data Using Conditions

# %%
# Filtering data using conditions
print(df.loc[df["batsman_runs"] == 9])
# Out:
# Empty DataFrame
# Columns: [match_id, inning, batting_team, bowling_team, over, ball, batter, bowler, non_striker, batsman_runs, extra_runs, total_runs, extras_type, is_wicket, player_dismissed, dismissal_kind, fielder]
# Index: []

# %% [markdown]
# ## 11. Handling Duplicates

# %% [markdown]
# ### Checking for Duplicates

# %%
# Remove duplicate rows
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %% [markdown]
# ### Removing Duplicate Rows

# %%
df.drop_duplicates(inplace=True) # Remove duplicate rows permanently
df
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball       batter         bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly        P Kumar  BB McCullum             0
# 1          0     2  BB McCullum        P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum        P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum        P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...   ...          ...            ...          ...           ...
# 260915     9     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     9     6      VR Iyer     AK Markram      SS Iyer             1
# 260917    10     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918    10     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919    10     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0              NaN
# 1                0           0           0          0              NaN
# 2                1           1       wides          0              NaN
# 3                0           0           0          0              NaN
# 4                0           0           0          0              NaN
# ...            ...         ...         ...        ...              ...
# 260915           0           1           0          0              NaN
# 260916           0           1           0          0              NaN
# 260917           0           1           0          0              NaN
# 260918           0           1           0          0              NaN
# 260919           0           1           0          0              NaN
#
#        dismissal_kind fielder
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ...               ...     ...
# 260915            NaN     NaN
# 260916            NaN     NaN
# 260917            NaN     NaN
# 260918            NaN     NaN
# 260919            NaN     NaN
#
# [260920 rows x 17 columns]

# %% [markdown]
# ## 12. Adding and Removing Columns

# %% [markdown]
# ### Adding a New Column

# %%
df['new_column2']=df['batsman_runs']+df['extra_runs']
df
# Out:
#         match_id          bowler  inning           batting_team  \
# 0         392190        MM Patel       2  Kolkata Knight Riders
# 1        1216496         L Ngidi       1       Rajasthan Royals
# 2         548341        J Theron       2          Pune Warriors
# 3         336028       VRV Singh       2         Mumbai Indians
# 4         734007  Sandeep Sharma       1    Sunrisers Hyderabad
# ...          ...             ...     ...                    ...
# 260915    501267    JEC Franklin       1  Kolkata Knight Riders
# 260916    501267    JEC Franklin       1  Kolkata Knight Riders
# 260917    733977        VR Aaron       1    Sunrisers Hyderabad
# 260918   1254060  Sandeep Sharma       1  Kolkata Knight Riders
# 260919    548313      MN Samuels       2        Kings XI Punjab
#
#                        bowling_team  over  ball       batsman    non_striker  \
# 0                  Rajasthan Royals    15     6    SC Ganguly  Yashpal Singh
# 1               Chennai Super Kings    19     3     JC Archer      TK Curran
# 2                   Deccan Chargers    16     1     SPD Smith       M Manhas
# 3                   Kings XI Punjab    19     1    SD Chitnis   CRD Fernando
# 4                   Kings XI Punjab    18     4       NV Ojha   MC Henriques
# ...                             ...   ...   ...           ...            ...
# 260915               Mumbai Indians    15     5     YK Pathan      JH Kallis
# 260916               Mumbai Indians    15     6     YK Pathan      JH Kallis
# 260917  Royal Challengers Bangalore     4     6     DA Warner       S Dhawan
# 260918          Sunrisers Hyderabad    13     4        N Rana    RA Tripathi
# 260919                Pune Warriors     1     4  AC Gilchrist    PC Valthaty
#
#         batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0                  6           1           7     noballs          0
# 1                  6           1           7     noballs          0
# 2                  6           1           7     noballs          0
# 3                  6           1           7     noballs          0
# 4                  6           1           7     noballs          0
# ...              ...         ...         ...         ...        ...
# 260915             0           0           0           0          0
# 260916             0           0           0           0          1
# 260917             0           0           0           0          0
# 260918             0           0           0           0          0
# 260919             0           0           0           0          0
#
#        player_dismissed dismissal_kind   fielder  new_column2
# 0                   NaN            NaN       NaN            7
# 1                   NaN            NaN       NaN            7
# 2                   NaN            NaN       NaN            7
# 3                   NaN            NaN       NaN            7
# 4                   NaN            NaN       NaN            7
# ...                 ...            ...       ...          ...
# 260915              NaN            NaN       NaN            0
# 260916        YK Pathan         caught  AN Ahmed            0
# 260917              NaN            NaN       NaN            0
# 260918              NaN            NaN       NaN            0
# 260919              NaN            NaN       NaN            0
#
# [260920 rows x 18 columns]

# %% [markdown]
# ### Dropping a Column

# %%
df = df.drop('new_column2', axis=1)
df
# Dropping a column named 'new_column'
# Out:
#         match_id          bowler  inning           batting_team  \
# 0         392190        MM Patel       2  Kolkata Knight Riders
# 1        1216496         L Ngidi       1       Rajasthan Royals
# 2         548341        J Theron       2          Pune Warriors
# 3         336028       VRV Singh       2         Mumbai Indians
# 4         734007  Sandeep Sharma       1    Sunrisers Hyderabad
# ...          ...             ...     ...                    ...
# 260915    501267    JEC Franklin       1  Kolkata Knight Riders
# 260916    501267    JEC Franklin       1  Kolkata Knight Riders
# 260917    733977        VR Aaron       1    Sunrisers Hyderabad
# 260918   1254060  Sandeep Sharma       1  Kolkata Knight Riders
# 260919    548313      MN Samuels       2        Kings XI Punjab
#
#                        bowling_team  over  ball       batsman    non_striker  \
# 0                  Rajasthan Royals    15     6    SC Ganguly  Yashpal Singh
# 1               Chennai Super Kings    19     3     JC Archer      TK Curran
# 2                   Deccan Chargers    16     1     SPD Smith       M Manhas
# 3                   Kings XI Punjab    19     1    SD Chitnis   CRD Fernando
# 4                   Kings XI Punjab    18     4       NV Ojha   MC Henriques
# ...                             ...   ...   ...           ...            ...
# 260915               Mumbai Indians    15     5     YK Pathan      JH Kallis
# 260916               Mumbai Indians    15     6     YK Pathan      JH Kallis
# 260917  Royal Challengers Bangalore     4     6     DA Warner       S Dhawan
# 260918          Sunrisers Hyderabad    13     4        N Rana    RA Tripathi
# 260919                Pune Warriors     1     4  AC Gilchrist    PC Valthaty
#
#         batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0                  6           1           7     noballs          0
# 1                  6           1           7     noballs          0
# 2                  6           1           7     noballs          0
# 3                  6           1           7     noballs          0
# 4                  6           1           7     noballs          0
# ...              ...         ...         ...         ...        ...
# 260915             0           0           0           0          0
# 260916             0           0           0           0          1
# 260917             0           0           0           0          0
# 260918             0           0           0           0          0
# 260919             0           0           0           0          0
#
#        player_dismissed dismissal_kind   fielder
# 0                   NaN            NaN       NaN
# 1                   NaN            NaN       NaN
# 2                   NaN            NaN       NaN
# 3                   NaN            NaN       NaN
# 4                   NaN            NaN       NaN
# ...                 ...            ...       ...
# 260915              NaN            NaN       NaN
# 260916        YK Pathan         caught  AN Ahmed
# 260917              NaN            NaN       NaN
# 260918              NaN            NaN       NaN
# 260919              NaN            NaN       NaN
#
# [260920 rows x 17 columns]

# %%
df   #Displaying DataFrame
# Out:
#         match_id          bowler  inning           batting_team  \
# 0         392190        MM Patel       2  Kolkata Knight Riders
# 1        1216496         L Ngidi       1       Rajasthan Royals
# 2         548341        J Theron       2          Pune Warriors
# 3         336028       VRV Singh       2         Mumbai Indians
# 4         734007  Sandeep Sharma       1    Sunrisers Hyderabad
# ...          ...             ...     ...                    ...
# 260915    501267    JEC Franklin       1  Kolkata Knight Riders
# 260916    501267    JEC Franklin       1  Kolkata Knight Riders
# 260917    733977        VR Aaron       1    Sunrisers Hyderabad
# 260918   1254060  Sandeep Sharma       1  Kolkata Knight Riders
# 260919    548313      MN Samuels       2        Kings XI Punjab
#
#                        bowling_team  over  ball       batsman    non_striker  \
# 0                  Rajasthan Royals    15     6    SC Ganguly  Yashpal Singh
# 1               Chennai Super Kings    19     3     JC Archer      TK Curran
# 2                   Deccan Chargers    16     1     SPD Smith       M Manhas
# 3                   Kings XI Punjab    19     1    SD Chitnis   CRD Fernando
# 4                   Kings XI Punjab    18     4       NV Ojha   MC Henriques
# ...                             ...   ...   ...           ...            ...
# 260915               Mumbai Indians    15     5     YK Pathan      JH Kallis
# 260916               Mumbai Indians    15     6     YK Pathan      JH Kallis
# 260917  Royal Challengers Bangalore     4     6     DA Warner       S Dhawan
# 260918          Sunrisers Hyderabad    13     4        N Rana    RA Tripathi
# 260919                Pune Warriors     1     4  AC Gilchrist    PC Valthaty
#
#         batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 0                  6           1           7     noballs          0
# 1                  6           1           7     noballs          0
# 2                  6           1           7     noballs          0
# 3                  6           1           7     noballs          0
# 4                  6           1           7     noballs          0
# ...              ...         ...         ...         ...        ...
# 260915             0           0           0           0          0
# 260916             0           0           0           0          1
# 260917             0           0           0           0          0
# 260918             0           0           0           0          0
# 260919             0           0           0           0          0
#
#        player_dismissed dismissal_kind   fielder
# 0                   NaN            NaN       NaN
# 1                   NaN            NaN       NaN
# 2                   NaN            NaN       NaN
# 3                   NaN            NaN       NaN
# 4                   NaN            NaN       NaN
# ...                 ...            ...       ...
# 260915              NaN            NaN       NaN
# 260916        YK Pathan         caught  AN Ahmed
# 260917              NaN            NaN       NaN
# 260918              NaN            NaN       NaN
# 260919              NaN            NaN       NaN
#
# [260920 rows x 17 columns]

# %% [markdown]
# ## 13. Sorting Data

# %% [markdown]
# ### Sorting by a Column

# %%
# Sorting data by total_runs in descending order
df=df.sort_values(by='total_runs', ascending=False)
print("\nSorted Data by total_runs:")
df
# Out:
# Sorted Data by total_runs:
#         match_id             bowler  inning                 batting_team  \
# 0         392190           MM Patel       2        Kolkata Knight Riders
# 45       1422136   Mukesh Choudhary       2          Sunrisers Hyderabad
# 65        392238           JDP Oram       2  Royal Challengers Bangalore
# 64        980999        KC Cariappa       1  Royal Challengers Bangalore
# 63        336033           MM Patel       2          Chennai Super Kings
# ...          ...                ...     ...                          ...
# 200625    829797            A Nehra       2             Rajasthan Royals
# 200624    335999          VRV Singh       1              Deccan Chargers
# 200623   1426290  Vijaykumar Vyshak       1               Gujarat Titans
# 200622    980901           R Bhatia       1               Mumbai Indians
# 260919    548313         MN Samuels       2              Kings XI Punjab
#
#                        bowling_team  over  ball          batsman  \
# 0                  Rajasthan Royals    15     6       SC Ganguly
# 45              Chennai Super Kings     1     5  Abhishek Sharma
# 65              Chennai Super Kings    18     1      LRPL Taylor
# 64                  Kings XI Punjab     6     5          V Kohli
# 63                 Rajasthan Royals    18     5        JA Morkel
# ...                             ...   ...   ...              ...
# 200625          Chennai Super Kings     0     2        AM Rahane
# 200624              Kings XI Punjab     7     4       VVS Laxman
# 200623  Royal Challengers Bengaluru    12     6      Rashid Khan
# 200622      Rising Pune Supergiants    13     1        AT Rayudu
# 260919                Pune Warriors     1     4     AC Gilchrist
#
#             non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# 0         Yashpal Singh             6           1           7     noballs
# 45              TM Head             6           1           7     noballs
# 65              V Kohli             6           1           7     noballs
# 64             CH Gayle             6           1           7     noballs
# 63              MS Gony             6           1           7     noballs
# ...                 ...           ...         ...         ...         ...
# 200625        SR Watson             0           0           0           0
# 200624        RG Sharma             0           0           0           0
# 200623        R Tewatia             0           0           0           0
# 200622  Harbhajan Singh             0           0           0           0
# 260919      PC Valthaty             0           0           0           0
#
#         is_wicket player_dismissed dismissal_kind fielder
# 0               0              NaN            NaN     NaN
# 45              0              NaN            NaN     NaN
# 65              0              NaN            NaN     NaN
# 64              0              NaN            NaN     NaN
# 63              0              NaN            NaN     NaN
# ...           ...              ...            ...     ...
# 200625          0              NaN            NaN     NaN
# 200624          0              NaN            NaN     NaN
# 200623          0              NaN            NaN     NaN
# 200622          0              NaN            NaN     NaN
# 260919          0              NaN            NaN     NaN
#
# [260920 rows x 17 columns]

# %% [markdown]
# ## 14. Grouping and Aggregation

# %% [markdown]
# ### Grouping by 'ball' and Calculating Aggregations

# %%
# Grouping by 'ball' and calculating average 'over'
grouped_df = df.groupby('ball')['over'].mean()
print("Average over by ball:")
print(grouped_df)
# Out:
# Average over by ball:
# ball
# 1      9.236674
# 2      9.216952
# 3      9.197776
# 4      9.178129
# 5      9.153214
# 6      9.127202
# 7      9.448688
# 8      9.919663
# 9     10.048889
# 10    11.100000
# 11    10.500000
# Name: over, dtype: float64

# %%
# Grouping by 'ball' and calculating median 'over'
grouped_df = df.groupby('ball')['over'].median()
print("Median of over by ball:")
print(grouped_df)
# Out:
# Median of over by ball:
# ball
# 1      9.0
# 2      9.0
# 3      9.0
# 4      9.0
# 5      9.0
# 6      9.0
# 7     10.0
# 8     10.0
# 9     11.0
# 10    13.0
# 11    10.5
# Name: over, dtype: float64

# %%
# Grouping by 'ball' and calculating variance 'over'
grouped_df = df.groupby('ball')['over'].var()
print("Variance of over by ball:")
print(grouped_df)
# Out:
# Variance of over by ball:
# ball
# 1      32.327694
# 2      32.233301
# 3      32.136332
# 4      32.035254
# 5      31.895832
# 6      31.753486
# 7      37.792093
# 8      41.495072
# 9      45.948492
# 10     45.610345
# 11    112.500000
# Name: over, dtype: float64

# %%
# Grouping by 'ball' and calculating standard deviation 'over'
grouped_df = df.groupby('ball')['over'].std()
print("Standard Deviation of 'over' by ball:")
print(grouped_df)
# Out:
# Standard Deviation of 'over' by ball:
# ball
# 1      5.685745
# 2      5.677438
# 3      5.668892
# 4      5.659969
# 5      5.647640
# 6      5.635023
# 7      6.147527
# 8      6.441667
# 9      6.778532
# 10     6.753543
# 11    10.606602
# Name: over, dtype: float64

# %% [markdown]
# ## 15. Renaming a Column

# %%
df = df.rename(columns={"batter": "batsman"})
# Renaming the column 'batter' to 'batsman' in the DataFrame
# The columns parameter is used to specify the old and new column names
# The change is temporary unless reassigned to df

# %%
df          # Displaying the DataFrame
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 15389     392190       2  Kolkata Knight Riders             Rajasthan Royals
# 180111   1216496       1       Rajasthan Royals          Chennai Super Kings
# 66653     548341       2          Pune Warriors              Deccan Chargers
# 10814     336028       2         Mumbai Indians              Kings XI Punjab
# 103698    734007       1    Sunrisers Hyderabad              Kings XI Punjab
# ...          ...     ...                    ...                          ...
# 57468     501267       1  Kolkata Knight Riders               Mumbai Indians
# 57469     501267       1  Kolkata Knight Riders               Mumbai Indians
# 100026    733977       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 194187   1254060       1  Kolkata Knight Riders          Sunrisers Hyderabad
# 60332     548313       2        Kings XI Punjab                Pune Warriors
#
#         over  ball       batsman          bowler    non_striker  batsman_runs  \
# 15389     15     6    SC Ganguly        MM Patel  Yashpal Singh             6
# 180111    19     3     JC Archer         L Ngidi      TK Curran             6
# 66653     16     1     SPD Smith        J Theron       M Manhas             6
# 10814     19     1    SD Chitnis       VRV Singh   CRD Fernando             6
# 103698    18     4       NV Ojha  Sandeep Sharma   MC Henriques             6
# ...      ...   ...           ...             ...            ...           ...
# 57468     15     5     YK Pathan    JEC Franklin      JH Kallis             0
# 57469     15     6     YK Pathan    JEC Franklin      JH Kallis             0
# 100026     4     6     DA Warner        VR Aaron       S Dhawan             0
# 194187    13     4        N Rana  Sandeep Sharma    RA Tripathi             0
# 60332      1     4  AC Gilchrist      MN Samuels    PC Valthaty             0
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 15389            1           7     noballs          0              NaN
# 180111           1           7     noballs          0              NaN
# 66653            1           7     noballs          0              NaN
# 10814            1           7     noballs          0              NaN
# 103698           1           7     noballs          0              NaN
# ...            ...         ...         ...        ...              ...
# 57468            0           0           0          0              NaN
# 57469            0           0           0          1        YK Pathan
# 100026           0           0           0          0              NaN
# 194187           0           0           0          0              NaN
# 60332            0           0           0          0              NaN
#
#        dismissal_kind   fielder  new_column1
# 15389             NaN       NaN            7
# 180111            NaN       NaN            7
# 66653             NaN       NaN            7
# 10814             NaN       NaN            7
# 103698            NaN       NaN            7
# ...               ...       ...          ...
# 57468             NaN       NaN            0
# 57469          caught  AN Ahmed            0
# 100026            NaN       NaN            0
# 194187            NaN       NaN            0
# 60332             NaN       NaN            0
#
# [260920 rows x 18 columns]

# %% [markdown]
# ## 16. Resetting and Setting Index

# %% [markdown]
# ### Setting a Multi-Level Index

# %%
df = df.set_index(["match_id", "bowler"])
# Setting 'match_id' and 'bowler' as the new multi-level index of the DataFrame
# This organizes data hierarchically, allowing for better grouping and analysis
# The change is temporary unless reassigned to df

# %%
df          # Displaying the DataFrame
# Out:
#                             inning                 batting_team  \
# match_id bowler
# 392190   MM Patel                2        Kolkata Knight Riders
# 1422136  Mukesh Choudhary        2          Sunrisers Hyderabad
# 392238   JDP Oram                2  Royal Challengers Bangalore
# 980999   KC Cariappa             1  Royal Challengers Bangalore
# 336033   MM Patel                2          Chennai Super Kings
# ...                            ...                          ...
# 829797   A Nehra                 2             Rajasthan Royals
# 335999   VRV Singh               1              Deccan Chargers
# 1426290  Vijaykumar Vyshak       1               Gujarat Titans
# 980901   R Bhatia                1               Mumbai Indians
# 548313   MN Samuels              2              Kings XI Punjab
#
#                                            bowling_team  over  ball  \
# match_id bowler
# 392190   MM Patel                      Rajasthan Royals    15     6
# 1422136  Mukesh Choudhary           Chennai Super Kings     1     5
# 392238   JDP Oram                   Chennai Super Kings    18     1
# 980999   KC Cariappa                    Kings XI Punjab     6     5
# 336033   MM Patel                      Rajasthan Royals    18     5
# ...                                                 ...   ...   ...
# 829797   A Nehra                    Chennai Super Kings     0     2
# 335999   VRV Singh                      Kings XI Punjab     7     4
# 1426290  Vijaykumar Vyshak  Royal Challengers Bengaluru    12     6
# 980901   R Bhatia               Rising Pune Supergiants    13     1
# 548313   MN Samuels                       Pune Warriors     1     4
#
#                                     batsman      non_striker  batsman_runs  \
# match_id bowler
# 392190   MM Patel                SC Ganguly    Yashpal Singh             6
# 1422136  Mukesh Choudhary   Abhishek Sharma          TM Head             6
# 392238   JDP Oram               LRPL Taylor          V Kohli             6
# 980999   KC Cariappa                V Kohli         CH Gayle             6
# 336033   MM Patel                 JA Morkel          MS Gony             6
# ...                                     ...              ...           ...
# 829797   A Nehra                  AM Rahane        SR Watson             0
# 335999   VRV Singh               VVS Laxman        RG Sharma             0
# 1426290  Vijaykumar Vyshak      Rashid Khan        R Tewatia             0
# 980901   R Bhatia                 AT Rayudu  Harbhajan Singh             0
# 548313   MN Samuels            AC Gilchrist      PC Valthaty             0
#
#                             extra_runs  total_runs extras_type  is_wicket  \
# match_id bowler
# 392190   MM Patel                    1           7     noballs          0
# 1422136  Mukesh Choudhary            1           7     noballs          0
# 392238   JDP Oram                    1           7     noballs          0
# 980999   KC Cariappa                 1           7     noballs          0
# 336033   MM Patel                    1           7     noballs          0
# ...                                ...         ...         ...        ...
# 829797   A Nehra                     0           0           0          0
# 335999   VRV Singh                   0           0           0          0
# 1426290  Vijaykumar Vyshak           0           0           0          0
# 980901   R Bhatia                    0           0           0          0
# 548313   MN Samuels                  0           0           0          0
#
#                            player_dismissed dismissal_kind fielder
# match_id bowler
# 392190   MM Patel                       NaN            NaN     NaN
# 1422136  Mukesh Choudhary               NaN            NaN     NaN
# 392238   JDP Oram                       NaN            NaN     NaN
# 980999   KC Cariappa                    NaN            NaN     NaN
# 336033   MM Patel                       NaN            NaN     NaN
# ...                                     ...            ...     ...
# 829797   A Nehra                        NaN            NaN     NaN
# 335999   VRV Singh                      NaN            NaN     NaN
# 1426290  Vijaykumar Vyshak              NaN            NaN     NaN
# 980901   R Bhatia                       NaN            NaN     NaN
# 548313   MN Samuels                     NaN            NaN     NaN
#
# [260920 rows x 15 columns]

# %% [markdown]
# ### Resetting the Index

# %%
df = df.reset_index()
# Resetting the index of the DataFrame, converting multi-level indices back into columns
# This restores 'match_id' and 'bowler' as regular columns if they were previously set as an index
# The change is temporary unless reassigned to df

# %%
df         # Displaying the DataFrame
# Out:
#         match_id             bowler  inning                 batting_team  \
# 0         392190           MM Patel       2        Kolkata Knight Riders
# 1        1422136   Mukesh Choudhary       2          Sunrisers Hyderabad
# 2         392238           JDP Oram       2  Royal Challengers Bangalore
# 3         980999        KC Cariappa       1  Royal Challengers Bangalore
# 4         336033           MM Patel       2          Chennai Super Kings
# ...          ...                ...     ...                          ...
# 260915    829797            A Nehra       2             Rajasthan Royals
# 260916    335999          VRV Singh       1              Deccan Chargers
# 260917   1426290  Vijaykumar Vyshak       1               Gujarat Titans
# 260918    980901           R Bhatia       1               Mumbai Indians
# 260919    548313         MN Samuels       2              Kings XI Punjab
#
#                        bowling_team  over  ball          batsman  \
# 0                  Rajasthan Royals    15     6       SC Ganguly
# 1               Chennai Super Kings     1     5  Abhishek Sharma
# 2               Chennai Super Kings    18     1      LRPL Taylor
# 3                   Kings XI Punjab     6     5          V Kohli
# 4                  Rajasthan Royals    18     5        JA Morkel
# ...                             ...   ...   ...              ...
# 260915          Chennai Super Kings     0     2        AM Rahane
# 260916              Kings XI Punjab     7     4       VVS Laxman
# 260917  Royal Challengers Bengaluru    12     6      Rashid Khan
# 260918      Rising Pune Supergiants    13     1        AT Rayudu
# 260919                Pune Warriors     1     4     AC Gilchrist
#
#             non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# 0         Yashpal Singh             6           1           7     noballs
# 1               TM Head             6           1           7     noballs
# 2               V Kohli             6           1           7     noballs
# 3              CH Gayle             6           1           7     noballs
# 4               MS Gony             6           1           7     noballs
# ...                 ...           ...         ...         ...         ...
# 260915        SR Watson             0           0           0           0
# 260916        RG Sharma             0           0           0           0
# 260917        R Tewatia             0           0           0           0
# 260918  Harbhajan Singh             0           0           0           0
# 260919      PC Valthaty             0           0           0           0
#
#         is_wicket player_dismissed dismissal_kind fielder
# 0               0              NaN            NaN     NaN
# 1               0              NaN            NaN     NaN
# 2               0              NaN            NaN     NaN
# 3               0              NaN            NaN     NaN
# 4               0              NaN            NaN     NaN
# ...           ...              ...            ...     ...
# 260915          0              NaN            NaN     NaN
# 260916          0              NaN            NaN     NaN
# 260917          0              NaN            NaN     NaN
# 260918          0              NaN            NaN     NaN
# 260919          0              NaN            NaN     NaN
#
# [260920 rows x 17 columns]

# %% [markdown]
# ## 17. Get the dimensions of the DataFrame

# %%
df.shape
# Out:
# (260920, 17)
